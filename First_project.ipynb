# %% [markdown]
# <a href="https://colab.research.google.com/github/Tezz86/Start/blob/main/First_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('bookings.csv', encoding='Windows-1251', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Hotel                      119390 non-null  object
#  1   Is Canceled                119390 non-null  int64
#  2   Lead Time                  119390 non-null  int64
#  3   arrival full date          119390 non-null  object
#  4   Arrival Date Year          119390 non-null  int64
#  5   Arrival Date Month         119390 non-null  object
#  6   Arrival Date Week Number   119390 non-null  int64
#  7   Arrival Date Day of Month  119390 non-null  int64
#  8   Stays in Weekend nights    119390 non-null  int64
#  9   Stays in week nights       119390 non-null  int64
#  10  stays total nights         119390 non-null  int64
#  11  Adults                     119390 non-null  int64
#  12  Children                   119386 non-null  float64
# ...

# %%
df.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
def lower_space(title):
  new_title = title.lower().replace(' ','_')
  return new_title

# %%
df = df.rename(columns=lower_space)

# %%
df['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df[df['is_canceled']==1].head(5)
# Out:
#            hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 8   Resort Hotel            1         85        2015-07-01               2015
# 9   Resort Hotel            1         75        2015-07-01               2015
# 10  Resort Hotel            1         23        2015-07-01               2015
# 27  Resort Hotel            1         60        2015-07-01               2015
# 32  Resort Hotel            1         96        2015-07-01               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 8                July                        27                          1
# 9                July                        27                          1
# 10               July                        27                          1
# 27               July                        27                          1
# 32               July                        27                          1
#
# ...

# %%
df[df['is_canceled']==0].country.value_counts()
# Out:
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
#        ...
# BHR        1
# DJI        1
# MLI        1
# NPL        1
# FRO        1
# Name: country, Length: 165, dtype: int64

# %% [markdown]
# ## Выделяем страны без отмен бронирований

# %%
df.query('is_canceled==0').country.value_counts()
# Out:
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
#        ...
# BHR        1
# DJI        1
# MLI        1
# NPL        1
# FRO        1
# Name: country, Length: 165, dtype: int64

# %%
df.loc[df.is_canceled==0].country.value_counts()
# Out:
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
#        ...
# BHR        1
# DJI        1
# MLI        1
# NPL        1
# FRO        1
# Name: country, Length: 165, dtype: int64

# %% [markdown]
# ## Среднее количество проведенных ночей по типу отеля

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.groupby('hotel').agg({'stays_total_nights':'mean'}).round(2)
# Out:
#               stays_total_nights
# hotel
# City Hotel                  2.98
# Resort Hotel                4.32

# %%
df.groupby('hotel').stays_total_nights.mean().round(2)
# Out:
# hotel
# City Hotel      2.98
# Resort Hotel    4.32
# Name: stays_total_nights, dtype: float64

# %% [markdown]
# ## Две колонки с типами комнат. Посчитать сколько раз значения отличаются

# %% [markdown]
# ### Посмотрим на эти **колонки**

# %%
df[['reserved_room_type','assigned_room_type']]
# Out:
#        reserved_room_type assigned_room_type
# 0                       C                  C
# 1                       C                  C
# 2                       A                  C
# 3                       A                  A
# 4                       A                  A
# ...                   ...                ...
# 119385                  A                  A
# 119386                  E                  E
# 119387                  D                  D
# 119388                  A                  A
# 119389                  A                  A
#
# [119390 rows x 2 columns]

# %% [markdown]
# ### Посчитаем количество различий 1 способом

# %%
df.query('reserved_room_type != assigned_room_type')[['reserved_room_type','assigned_room_type']]
# Out:
#        reserved_room_type assigned_room_type
# 2                       A                  C
# 12                      D                  E
# 15                      D                  E
# 17                      A                  E
# 18                      A                  G
# ...                   ...                ...
# 119273                  A                  K
# 119274                  A                  K
# 119289                  E                  F
# 119297                  D                  F
# 119357                  A                  D
#
# [14917 rows x 2 columns]

# %% [markdown]
# ### Посчитаем количество различий 2 способом

# %%
len(df.loc[df.reserved_room_type != df.assigned_room_type])
# Out:
# 14917

# %% [markdown]
# ### Считаем в каком году какой месяц был самым популярным

# %%
df.groupby('arrival_date_month').agg({'arrival_date_year':'count'})
# Out:
#                     arrival_date_year
# arrival_date_month
# April                           11089
# August                          13877
# December                         6780
# February                         8068
# January                          5929
# July                            12661
# June                            10939
# March                            9794
# May                             11791
# November                         6794
# October                         11160
# September                       10508

# %%
df.query('arrival_date_year==2016').arrival_date_month.value_counts()
# Out:
# October      6203
# May          5478
# April        5428
# September    5394
# June         5292
# August       5063
# March        4824
# July         4572
# November     4454
# February     3891
# December     3860
# January      2248
# Name: arrival_date_month, dtype: int64

# %%
df.query('arrival_date_year==2017').arrival_date_month.value_counts()
# Out:
# May         6313
# April       5661
# June        5647
# July        5313
# March       4970
# August      4925
# February    4177
# January     3681
# Name: arrival_date_month, dtype: int64

# %%
df.groupby('arrival_date_year').arrival_date_month.agg(pd.Series.mode)
# Out:
# arrival_date_year
# 2015    September
# 2016      October
# 2017          May
# Name: arrival_date_month, dtype: object

# %% [markdown]
# ### Считаем какой месяц был самым отменяемым

# %%
df[(df['hotel']=="City Hotel")&(df['is_canceled']==1)].groupby('arrival_date_year').arrival_date_month.agg(pd.Series.mode)
# Out:
# arrival_date_year
# 2015    September
# 2016      October
# 2017          May
# Name: arrival_date_month, dtype: object

# %%
df.query('hotel=="City Hotel" and is_canceled==1').groupby('arrival_date_year').arrival_date_month.value_counts()
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             1543
#                    October               1321
#                    August                1232
#                    July                   939
#                    December               668
#                    November               301
# 2016               October               1947
#                    June                  1720
#                    September             1567
#                    April                 1539
#                    May                   1436
#                    November              1360
#                    August                1247
#                    March                 1108
#                    December              1072
#                    July                  1043
#                    February               930
#                    January                438
# 2017               May                   2217
#                    April                 1926
# ...

# %%
df.adults.mean()
# Out:
# 1.8564033838679956

# %%
df.babies.mean()
# Out:
# 0.007948739425412514

# %%
df.children.mean()
# Out:
# 0.10388990333874994

# %%
df[['adults','children','babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
df[['adults','children','babies']].describe()
# Out:
#               adults       children         babies
# count  119390.000000  119386.000000  119390.000000
# mean        1.856403       0.103890       0.007949
# std         0.579261       0.398561       0.097436
# min         0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000
# 75%         2.000000       0.000000       0.000000
# max        55.000000      10.000000      10.000000

# %%
df['total_kids'] = df['children'] + df['babies']

# %%
df['total_kids'].sort_values(ascending=False)
# Out:
# 328       10.0
# 46619     10.0
# 78656      9.0
# 19718      3.0
# 107837     3.0
#           ...
# 119389     0.0
# 40600      NaN
# 40667      NaN
# 40679      NaN
# 41160      NaN
# Name: total_kids, Length: 119390, dtype: float64

# %%
df.total_kids.sort_values(ascending=False).head(10)
# Out:
# 328       10.0
# 46619     10.0
# 78656      9.0
# 19718      3.0
# 107837     3.0
# 24409      3.0
# 90790      3.0
# 95227      3.0
# 106216     3.0
# 27246      3.0
# Name: total_kids, dtype: float64

# %%
df.iloc[19718]
# Out:
# hotel                        Resort Hotel
# is_canceled                             0
# lead_time                               0
# arrival_full_date              2016-01-01
# arrival_date_year                    2016
# arrival_date_month                January
# arrival_date_week_number                1
# arrival_date_day_of_month               1
# stays_in_weekend_nights                 0
# stays_in_week_nights                    1
# stays_total_nights                      1
# adults                                  2
# children                              3.0
# babies                                  0
# meal                                   BB
# country                               PRT
# reserved_room_type                      A
# assigned_room_type                      G
# customer_type                   Transient
# reservation_status              Check-Out
# reservation_status_date        2016-01-02
# total_kids                            3.0
# Name: 19718, dtype: object

# %%
df.groupby('hotel').agg({'total_kids':'mean'}).round(2)
# Out:
#               total_kids
# hotel
# City Hotel          0.10
# Resort Hotel        0.14

# %%
df.query('total_kids>0')
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 13      Resort Hotel            0         18        2015-07-01
# 45      Resort Hotel            1         47        2015-07-02
# 55      Resort Hotel            0          1        2015-07-02
# 65      Resort Hotel            0         10        2015-07-03
# 87      Resort Hotel            1         79        2015-07-03
# ...              ...          ...        ...               ...
# 119270    City Hotel            0          0        2017-08-29
# 119287    City Hotel            0        167        2017-08-27
# 119293    City Hotel            0        243        2017-08-30
# 119318    City Hotel            0        160        2017-08-29
# 119319    City Hotel            0         45        2017-08-28
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 13                   2015               July                        27
# ...

# %%
def has_kids(row):
  if row > 0:
    return True
  return False

# %%
df['has_kids1'] = df.total_kids.apply(has_kids)

# %%
df['has_kids2'] = df.total_kids > 0

# %%
df.shape
# Out:
# (119390, 24)

# %%
df.query('is_canceled==1 and has_kids1==False')
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 8       Resort Hotel            1         85        2015-07-01
# 9       Resort Hotel            1         75        2015-07-01
# 10      Resort Hotel            1         23        2015-07-01
# 27      Resort Hotel            1         60        2015-07-01
# 32      Resort Hotel            1         96        2015-07-01
# ...              ...          ...        ...               ...
# 110280    City Hotel            1        132        2017-04-25
# 111355    City Hotel            1          4        2017-06-05
# 111924    City Hotel            1          7        2017-05-31
# 111925    City Hotel            1          6        2017-07-17
# 117295    City Hotel            1          0        2017-08-02
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 8                    2015               July                        27
# ...

# %%
df.query('is_canceled==1 and has_kids2==False')
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 8       Resort Hotel            1         85        2015-07-01
# 9       Resort Hotel            1         75        2015-07-01
# 10      Resort Hotel            1         23        2015-07-01
# 27      Resort Hotel            1         60        2015-07-01
# 32      Resort Hotel            1         96        2015-07-01
# ...              ...          ...        ...               ...
# 110280    City Hotel            1        132        2017-04-25
# 111355    City Hotel            1          4        2017-06-05
# 111924    City Hotel            1          7        2017-05-31
# 111925    City Hotel            1          6        2017-07-17
# 117295    City Hotel            1          0        2017-08-02
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 8                    2015               July                        27
# ...

# %%
df.groupby('has_kids1').is_canceled.value_counts()
# Out:
# has_kids1  is_canceled
# False      0              69093
#            1              40965
# True       0               6073
#            1               3259
# Name: is_canceled, dtype: int64

# %%
df.groupby('has_kids1').is_canceled.value_counts()[1]
# Out:
# 40965

# %%
len(df[df['has_kids1']==False])
# Out:
# 110058

# %%
Churn_rate = [round(df.groupby('has_kids1').is_canceled.value_counts()[1]/len(df[df['has_kids1']==False]),ndigits=4)*100, \
              round(df.groupby('has_kids1').is_canceled.value_counts()[3]/len(df[df['has_kids1']==True]),ndigits=4)*100\
              ]

# %%
Churn_rate
# Out:
# [37.22, 34.92]
