# %% [markdown]
# <a href="https://colab.research.google.com/github/Tezz86/Start/blob/main/Karpov_python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://drive.google.com/file/d/1IHSpWP-IveRJ_1ZrQgYrxxpTcEyb-sqL/view?usp=sharing

# %%
! gdown --id 1IHSpWP-IveRJ_1ZrQgYrxxpTcEyb-sqL
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1IHSpWP-IveRJ_1ZrQgYrxxpTcEyb-sqL
# To: /content/lesson_1_data.csv
# 100% 36.9k/36.9k [00:00<00:00, 64.2MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/lesson_1_data.csv', encoding='Windows-1251', sep=';')

# %%
df.head()
# Out:
#      Номер     Дата создания       Дата оплаты                        Title  \
# 0  1062823  01.12.2019 10:50  01.12.2019 10:52      Курс обучения «Эксперт»
# 1  1062855  01.12.2019 20:53  01.12.2019 21:27      Курс обучения «Эксперт»
# 2  1062856  01.12.2019 21:43               NaN   Курс обучения «Специалист»
# 3  1062880   03.12.2019 0:18               NaN  Курс обучения «Консультант»
# 4  1062899  03.12.2019 21:43               NaN      Курс обучения «Эксперт»
#
#      Статус  Заработано                          Город   Платежная система
# 0  Завершен     29597.5                           Чита  Сбербанк эквайринг
# 1  Завершен     17450.3                      Краснодар        Яндекс.Касса
# 2   Отменен         0.0                            NaN                 NaN
# 3   Отменен         0.0  г.Москва и Московская область                 NaN
# 4   Отменен         0.0  г.Москва и Московская область                 NaN

# %%
df.shape
# Out:
# (292, 8)

# %%
df.columns
# Out:
# Index(['Номер', 'Дата создания', 'Дата оплаты', 'Title', 'Статус',
#        'Заработано', 'Город', 'Платежная система'],
#       dtype='object')

# %%
df['Номер']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-faa8e1f96e18> in <cell line: 1>()
# ----> 1 df['Номер']
#
# NameError: name 'df' is not defined

# %%
df.groupby('Платежная система')

# %%
url = 'https://stepik.org/media/attachments/lesson/360340/2_taxi_nyc.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp 01  pcp 06  pcp 24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
df.shape
# Out:
# (29101, 14)

# %%
df.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
df = df.rename(columns={'pcp 01':'pcp_01', 'pcp 06':'pcp_06', 'pcp 24': 'pcp_24'
})

# %%
df.dtypes
# Out:
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp_01          float64
# pcp_06          float64
# pcp_24          float64
# sd              float64
# dtype: object

# %%
df.head(15)
# Out:
#               pickup_dt pickup_month        borough  pickups hday  spd   vsb  \
# 0   2015-01-01 01:00:00          Jan          Bronx      152    Y  5.0  10.0
# 1   2015-01-01 01:00:00          Jan       Brooklyn     1519    Y  5.0  10.0
# 2   2015-01-01 01:00:00          Jan            EWR        0    Y  5.0  10.0
# 3   2015-01-01 01:00:00          Jan      Manhattan     5258    Y  5.0  10.0
# 4   2015-01-01 01:00:00          Jan         Queens      405    Y  5.0  10.0
# 5   2015-01-01 01:00:00          Jan  Staten Island        6    Y  5.0  10.0
# 6   2015-01-01 01:00:00          Jan            NaN        4    Y  5.0  10.0
# 7   2015-01-01 02:00:00          Jan          Bronx      120    Y  3.0  10.0
# 8   2015-01-01 02:00:00          Jan       Brooklyn     1229    Y  3.0  10.0
# 9   2015-01-01 02:00:00          Jan            EWR        0    Y  3.0  10.0
# 10  2015-01-01 02:00:00          Jan      Manhattan     4345    Y  3.0  10.0
# ...

# %%
df[df['borough'] == 'E']
# Out:
#                  pickup_dt pickup_month borough  pickups hday  spd   vsb  \
# 2      2015-01-01 01:00:00          Jan     EWR        0    Y  5.0  10.0
# 9      2015-01-01 02:00:00          Jan     EWR        0    Y  3.0  10.0
# 16     2015-01-01 03:00:00          Jan     EWR        0    Y  5.0  10.0
# 23     2015-01-01 04:00:00          Jan     EWR        0    Y  5.0  10.0
# 30     2015-01-01 05:00:00          Jan     EWR        0    Y  5.0  10.0
# ...                    ...          ...     ...      ...  ...  ...   ...
# 29070  2015-06-30 19:00:00          Jun     EWR        0    N  5.0  10.0
# 29077  2015-06-30 20:00:00          Jun     EWR        0    N  8.0  10.0
# 29084  2015-06-30 21:00:00          Jun     EWR        0    N  7.0  10.0
# 29090  2015-06-30 22:00:00          Jun     EWR        0    N  5.0  10.0
# 29096  2015-06-30 23:00:00          Jun     EWR        0    N  7.0  10.0
#
#        temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
df['pickups'].hist()
# Out:
# <Axes: >

# %%
df.pickups.sum()
# Out:
# 14265773

# %%
df.groupby('borough')['pickups'].agg(['count','mean'])
# Out:
#                count         mean
# borough
# Bronx           4343    50.667050
# Brooklyn        4343   534.431269
# EWR             4343     0.024177
# Manhattan       4343  2387.253281
# Queens          4343   309.354824
# Staten Island   4343     1.601888

# %%
df.groupby('borough').agg({'pickups':'sum'}).idxmax()
# Out:
# pickups    Manhattan
# dtype: object

# %%
df.sort_values('borough')
# Out:
#                  pickup_dt pickup_month borough  pickups hday        spd  \
# 0      2015-01-01 01:00:00          Jan   Bronx      152    Y   5.000000
# 20290  2015-05-08 02:00:00          May   Bronx       20    N   0.000000
# 6405   2015-02-10 11:00:00          Feb   Bronx       31    N  10.000000
# 20297  2015-05-08 03:00:00          May   Bronx       19    N   3.000000
# 6398   2015-02-10 10:00:00          Feb   Bronx       32    N   9.500000
# ...                    ...          ...     ...      ...  ...        ...
# 29060  2015-06-30 17:00:00          Jun     NaN        1    N   7.666667
# 29067  2015-06-30 18:00:00          Jun     NaN        2    N   6.333333
# 29074  2015-06-30 19:00:00          Jun     NaN        4    N   5.000000
# 29081  2015-06-30 20:00:00          Jun     NaN        5    N   8.000000
# 29100  2015-06-30 23:00:00          Jun     NaN        3    N   7.000000
#
#         vsb  temp  dewp     slp  pcp_01  pcp_06  pcp_24   sd
# ...

# %%
df.groupby(['borough','hday']).agg({'pickups':'mean'})
# Out:
#                         pickups
# borough       hday
# Bronx         N       50.771073
#               Y       48.065868
# Brooklyn      N      534.727969
#               Y      527.011976
# EWR           N        0.023467
#               Y        0.041916
# Manhattan     N     2401.302921
#               Y     2035.928144
# Queens        N      308.899904
#               Y      320.730539
# Staten Island N        1.606082
#               Y        1.497006

# %%
df.groupby(['borough','hday'])['pickups'].agg(['mean'])
# Out:
#                            mean
# borough       hday
# Bronx         N       50.771073
#               Y       48.065868
# Brooklyn      N      534.727969
#               Y      527.011976
# EWR           N        0.023467
#               Y        0.041916
# Manhattan     N     2401.302921
#               Y     2035.928144
# Queens        N      308.899904
#               Y      320.730539
# Staten Island N        1.606082
#               Y        1.497006

# %%
df.groupby(['borough','pickup_month']).agg({'pickups':'sum'}).sort_values('pickups', ascending=False)
# Out:
#                             pickups
# borough       pickup_month
# Manhattan     Jun           1995388
#               May           1888800
#               Feb           1718571
#               Mar           1661261
#               Apr           1648278
#               Jan           1455543
# Brooklyn      Jun            482466
#               May            476087
#               Apr            378095
#               Mar            346726
#               Feb            328650
#               Jan            309011
# Queens        Jun            286311
#               May            275893
#               Mar            219561
#               Apr            216857
#               Feb            185695
#               Jan            159211
# Bronx         May             53037
#               Jun             49006
#               Apr             34617
#               Mar             32232
#               Feb             28694
#               Jan             22461
# ...

# %%
def temp_to_celcius(row):
  return (row['temp']-32)*5/9

# %%
df['temp_cel'] = df.apply(temp_to_celcius, axis = 1)

# %%
df.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp_01  pcp_06  pcp_24   sd  temp_cel
# 0   7.0  1023.5     0.0     0.0     0.0  0.0 -1.111111
# 1   7.0  1023.5     0.0     0.0     0.0  0.0 -1.111111
# 2   7.0  1023.5     0.0     0.0     0.0  0.0 -1.111111
# 3   7.0  1023.5     0.0     0.0     0.0  0.0 -1.111111
# 4   7.0  1023.5     0.0     0.0     0.0  0.0 -1.111111

# %%
def temp_to_celcius(t):
  return (t-32)*5/9

# %%
temp_to_celcius(df['temp'])
# Out:
# 0        -1.111111
# 1        -1.111111
# 2        -1.111111
# 3        -1.111111
# 4        -1.111111
#            ...
# 29096    23.888889
# 29097    23.888889
# 29098    23.888889
# 29099    23.888889
# 29100    23.888889
# Name: temp, Length: 29101, dtype: float64
